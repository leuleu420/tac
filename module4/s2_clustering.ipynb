# %% [markdown]
# # Clustering de documents

# %% [markdown]
# Permet de créer automatiquement des catégories qui ne sont pas annotées dans le corpus CAMille

# %% [markdown]
# ## Imports

# %%
import collections
import os
import string
import sys

import pandas as pd
from nltk import word_tokenize
from nltk.corpus import stopwords
from pprint import pprint
from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import PCA
import numpy as np
import matplotlib.pyplot as plt
from scipy.spatial.distance import cosine

# %%
import nltk

nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /Users/laure-
# [nltk_data]     annemassart/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
data_path = "../data/txt/"

# %% [markdown]
# ## Choisir une décennie

# %%
DECADE = '1950'

# %% [markdown]
# ## Charger tous les  fichiers de la décennie et en créer une liste de textes

# %%
files = [f for f in sorted(os.listdir(data_path)) if f"_{DECADE[:-1]}" in f]

# %%
# Exemple de fichiers
files[:5]
# Out:
# ['KB_JB838_1950-01-06_01-00002.txt',
#  'KB_JB838_1950-01-07_01-00013.txt',
#  'KB_JB838_1950-01-08_01-00011.txt',
#  'KB_JB838_1950-01-10_01-00006.txt',
#  'KB_JB838_1950-01-15_01-00010.txt']

# %%
# Ouvrir les textes
texts = [open(data_path + f, "r", encoding="utf-8").read() for f in files]

# %%
# Exemple de textes
texts[0][:400]
# Out:
# '/ LE SOIR Une importante manifestation franco-belge Le Comité franco-belge du Commerce, de l’Industrie et de l’Agriculture qui. au cours de l’année écoulée et dans les circonstances les plus difficiles a rendu aux relations économiques entre les deux pays des services considérables, donnera le 12 janvier, à 19 h. 30, un dîner à l’occasion de l’anniversaire de son installation. Ce comité, qui fonct'

# %% [markdown]
# ## Vectoriser les documents à l'aide de TF-IDF

# %%
# Création d'une fonction de pré-traitement
# TFIDF sur l'ensemble des documents avec pré-processing qui va tokenizeer le texte et enlever la ponctuation
def preprocessing(text, stem=True):
    """ Tokenize text and remove punctuation """
    text = text.translate(string.punctuation)
    tokens = word_tokenize(text)
    return tokens

# %% [markdown]
# ### Instancier le modèle TF-IDF avec ses arguments

# %%
# max/min_df : pourcentage max/min de fréquence des termes dans les documents
# Peut être adapté pour rendre + pertineent
vectorizer = TfidfVectorizer(
    tokenizer=preprocessing,
    stop_words=stopwords.words('french'),
    max_df=0.5,
    min_df=0.1,
    lowercase=True)

# %% [markdown]
# ### Construire la matrice de vecteurs à l'aide de la fonction `fit_transform`

# %%
tfidf_vectors = vectorizer.fit_transform(texts)

# %%
# Détail de la matrice
tfidf_vectors
# Out:
# <1000x3506 sparse matrix of type '<class 'numpy.float64'>'
# 	with 703414 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ### Imprimer le vecteur tf-IDF du premier document

# %%
pd.Series(
    tfidf_vectors[0].toarray()[0],
    index=vectorizer.get_feature_names_out()
    ).sort_values(ascending=False)
# Out:
# parti           0.276898
# loyer           0.152154
# janvier         0.147984
# populaire       0.147399
# propriétaire    0.143645
#                   ...
# enquête         0.000000
# ent             0.000000
# entend          0.000000
# enthousiasme    0.000000
# italiens        0.000000
# Length: 3506, dtype: float64

# %% [markdown]
# ## Comprendre les vecteurs et leurs "distances"

# %%
# Evaluer la distance entre les 2 vecteurs
# Plus les vecteurs sont distants, plus le chiffre est proche de 1
cosine([1, 2, 3], [1, 2, 3])
# Out:
# 0

# %%
cosine([1, 2, 3], [1, 2, 2])
# Out:
# 0.02004211298777725

# %%
cosine([1, 2, 3], [2, 2, 2])
# Out:
# 0.07417990022744858

# %% [markdown]
# ### Tests sur nos documents

# %%
tfidf_array = tfidf_vectors.toarray()

# %%
# Vecteur du document 0
tfidf_array[0]
# Out:
# array([0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#        0.03783191])

# %%
# Vecteur du document 1
tfidf_array[1]
# Out:
# array([0.       , 0.0067046, 0.       , ..., 0.       , 0.       ,
#        0.       ])

# %%
cosine(tfidf_array[0], tfidf_array[1])
# Out:
# 0.9314315949045398

# %% [markdown]
# ## Appliquer un algorithme de clustering sur les vecteurs TF-IDF des documents

# %% [markdown]
# Pour en savoir plus sur le KMeans clustering :
# - https://medium.com/dataseries/k-means-clustering-explained-visually-in-5-minutes-b900cc69d175

# %% [markdown]
# ### Définir un nombre de clusters

# %%
N_CLUSTERS = 5

# %% [markdown]
# ### Instancier le modèle K-Means et ses arguments

# %%
km_model = KMeans(n_clusters=N_CLUSTERS)

# %% [markdown]
# ### Appliquer le clustering à l'aide de la fonction `fit_predict`

# %%
clusters = km_model.fit_predict(tfidf_vectors)

# %%
clustering = collections.defaultdict(list)

for idx, label in enumerate(clusters):
    clustering[label].append(files[idx])

# %%
pprint(dict(clustering))
# Out:
# {0: ['KB_JB838_1950-01-22_01-00014.txt',
#      'KB_JB838_1950-02-15_01-00011.txt',
#      'KB_JB838_1950-02-16_01-00014.txt',
#      'KB_JB838_1950-02-25_01-00013.txt',
#      'KB_JB838_1950-06-04_01-00016.txt',
#      'KB_JB838_1950-06-11_01-00015.txt',
#      'KB_JB838_1950-09-08_01-00012.txt',
#      'KB_JB838_1950-09-09_01-00011.txt',
#      'KB_JB838_1950-10-05_01-00012.txt',
#      'KB_JB838_1950-10-15_01-00018.txt',
#      'KB_JB838_1950-10-27_01-00014.txt',
#      'KB_JB838_1950-11-04_01-00014.txt',
#      'KB_JB838_1950-11-24_01-00013.txt',
#      'KB_JB838_1950-12-28_01-00012.txt',
#      'KB_JB838_1950-12-29_01-00014.txt',
#      'KB_JB838_1951-01-16_01-00010.txt',
#      'KB_JB838_1951-01-23_01-00011.txt',
#      'KB_JB838_1951-02-24_01-00015.txt',
#      'KB_JB838_1951-03-15_01-00016.txt',
#      'KB_JB838_1951-03-22_01-00012.txt',
#      'KB_JB838_1951-04-15_01-00019.txt',
#      'KB_JB838_1951-05-23_01-00012.txt',
#      'KB_JB838_1951-05-26_01-00014.txt',
# ...

# %% [markdown]
# ## Visualiser les clusters

# %% [markdown]
# ### Réduire les vecteurs à 2 dimensions à l'aide de l'algorithme PCA
# Cette étape est nécessaire afin de visualiser les documents dans un espace 2D
#
# https://fr.wikipedia.org/wiki/Analyse_en_composantes_principales

# %%
pca = PCA(n_components=2)
reduced_vectors = pca.fit_transform(tfidf_vectors.toarray())

# %%
reduced_vectors[:10]
# Out:
# array([[-0.32577068,  0.11394049],
#        [ 0.11347135, -0.30167119],
#        [ 0.44366539, -0.25250782],
#        [-0.23888529, -0.03765241],
#        [-0.05185305, -0.10498811],
#        [ 0.61288627,  0.50398816],
#        [-0.20409261, -0.03497769],
#        [-0.19467468, -0.03777999],
#        [ 0.62386851,  0.45618287],
#        [ 0.15641292, -0.01409993]])

# %% [markdown]
# ### Générer le plot

# %%
x_axis = reduced_vectors[:, 0]
y_axis = reduced_vectors[:, 1]

plt.figure(figsize=(10,10))
scatter = plt.scatter(x_axis, y_axis, s=100, c=clusters)

# Ajouter les centroïdes
centroids = pca.transform(km_model.cluster_centers_)
plt.scatter(centroids[:, 0], centroids[:, 1],  marker = "x", s=100, linewidths = 2, color='black')

# Ajouter la légende
plt.legend(handles=scatter.legend_elements()[0], labels=set(clusters), title="Clusters")

# %% [markdown]
# Point négatif : les clusters 1 et 3 pourraient être fusionnés. On peut modifier le nombre de clusters dans [21]
